# %%
from spectral import imshow, view_cube
import spectral.io.envi as envi
img = envi.open('capture/daun.hdr', 'capture/daun.raw')
img.shape
img.bands
# Out:
# Header parameter names converted to lower case.
# C:\Users\user\Anaconda3\lib\site-packages\spectral\io\envi.py:195: UserWarning: Parameters with non-lowercase names encountered and converted to lowercase. To retain source file parameter name capitalization, set spectral.setttings.envi_support_nonlowercase_params to True.
#   warnings.warn(msg)

# %%
lib = envi.open('capture/madu.hdr')
# Out:
# Header parameter names converted to lower case.
# C:\Users\user\Anaconda3\lib\site-packages\spectral\io\envi.py:195: UserWarning: Parameters with non-lowercase names encountered and converted to lowercase. To retain source file parameter name capitalization, set spectral.setttings.envi_support_nonlowercase_params to True.
#   warnings.warn(msg)
# 	Data Source:   '.\capture/madu.raw'
# 	# Rows:            512
# 	# Samples:         512
# 	# Bands:           224
# 	Interleave:        BIL
# 	Quantization:  16 bits
# 	Data format:    uint16

# %%
imshow(img, (110, 5, 18))
# Out:
# ImageView object:
#   Display bands       :  (110, 5, 18)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [218.0, 359.0]
#     G: [208.0, 237.0]
#     B: [206.0, 243.0]

# %%
x = 100
y = 100
w = 100
h = 100

region = img[y:y+h, x:x+w, :224]
imshow(region, (63, 54, 18))
# Out:
# ImageView object:
#   Display bands       :  (63, 54, 18)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [223.0, 276.0]
#     G: [222.0, 266.0]
#     B: [208.0, 237.0]
